# %%
import numpy as np
import matplotlib.pyplot as plt
n = 30 #number of points

#generate space of parameter
theta = np.linspace(0, 2.0*np.pi, n)

a, b,  r = 0.0, 0.0, 5.0

#convert degrees to coordinates
x = a + r*np.cos(theta)
y = b + r*np.sin(theta)

#plot the circle 
plt.plot(x, y)
plt.show()

# %%
#Stochastically sample from the circle, with some randomness
x2 = np.random.uniform(-0.75, 0.75, n) + x
y2 = np.random.uniform(-0.75, 0.75, n) + y 
fig, ax = plt.subplots()
ax.scatter(x2, y2)
plt.show()

# %% [markdown]
# We want to compute a Vietoris-Rips complex on this according to the method described by Afra Zomoridian in "Fast Construction of a Vietoris-Rips Complex". This algorithm functions in two stps
